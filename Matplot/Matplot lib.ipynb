# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Line charts -- generate randomly the x and y axis
x =np.linspace(0,20,1000)
y = np.sin(x)+0.2*x

# %%
#plotting the axis
plt.plot(x,y)

# %%
#Axis labels
plt.plot(x,y)
plt.xlabel('input')
plt.ylabel('output')
plt.title('My plot');

# %%
#scatter plot
x = np.random.randn(200,2)
plt.scatter(x[:,0],x[:,1])

# %%
#Histogram -- random normal
x = np.random.randn(10000)
plt.hist(x ,bins = 100);

# %%
#Histogram -- random normal
x = np.random.random(10000)
plt.hist(x ,bins = 100);

# %%
#Plotting Images
import requests
from PIL import Image
from io import BytesIO
from IPython.display import Image
from PIL import Image

# %%
# image import from local machine
filepath = 'D:/GIT1/Machine Learning/ML Libraries/Machine-Learning-Libraries/Matplot/mona.jpeg'

# %%
# Display the image -- method 1
im=Image(filename=filepath) 
im

# %%
#Display image --method 2
image = Image.open(filepath)
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x600>

# %%
arr = np.array(image)
arr
# Out:
# array([[[ 73,  81,  70],
#         [ 83,  91,  78],
#         [ 72,  80,  67],
#         ...,
#         [ 83,  96,  68],
#         [ 82,  95,  67],
#         [ 76,  89,  61]],
#
#        [[ 86,  97,  83],
#         [ 80,  91,  77],
#         [ 64,  75,  59],
#         ...,
#         [ 83,  94,  64],
#         [ 84,  97,  67],
#         [ 81,  94,  64]],
#
#        [[ 96, 107,  93],
#         [ 75,  86,  70],
#         [ 55,  66,  50],
#         ...,
#         [ 77,  88,  56],
#         [ 83,  97,  64],
#         [ 86, 100,  67]],
#
#        ...,
#
#        [[ 41,  40,  19],
#         [ 43,  42,  21],
#         [ 46,  48,  27],
#         ...,
#         [ 47,  49,  25],
#         [ 48,  47,  26],
#         [ 47,  46,  25]],
#
#        [[ 45,  44,  23],
#         [ 44,  43,  23],
#         [ 46,  48,  27],
#         ...,
#         [ 46,  46,  22],
#         [ 46,  45,  24],
#         [ 48,  46,  25]],
#
#        [[ 59,  58,  38],
#         [ 48,  50,  29],
#         [ 47,  49,  28],
# ...

# %%
#check shape
arr.shape
# Out:
# (600, 960, 3)

# %%
#plot image --.imshow()
plt.imshow(arr)

# %%
#convert RGB to greyscale -- mean of RGB
gray = arr.mean(axis = 2)

# %%
#check shape of the IMAGE
gray.shape
# Out:
# (600, 960)

# %%
plt.imshow(gray)

# %%
#plot to greyscale
plt.imshow(gray,cmap = 'gray')
