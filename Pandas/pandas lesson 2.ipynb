# %%
import pandas as pd

# %%
#Read from csv
df = pd.read_csv('D:/Toyota.csv')
df
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
#Checking first and last 50 rows
df.head(50)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1436 non-null   int64
#  1   Price       1436 non-null   int64
#  2   Age         1336 non-null   float64
#  3   KM          1436 non-null   object
#  4   FuelType    1336 non-null   object
#  5   HP          1436 non-null   object
#  6   MetColor    1286 non-null   float64
#  7   Automatic   1436 non-null   int64
#  8   CC          1436 non-null   int64
#  9   Doors       1436 non-null   object
#  10  Weight      1436 non-null   int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 123.5+ KB

# %%
#Selecting Rows and Columns
df.columns
# Out:
# Index(['Unnamed: 0', 'Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor',
#        'Automatic', 'CC', 'Doors', 'Weight'],
#       dtype='object')

# %%
#Select single columns
df['FuelType']
# Out:
# 0       Diesel
# 1       Diesel
# 2       Diesel
# 3       Diesel
# 4       Diesel
#          ...
# 1431    Petrol
# 1432    Petrol
# 1433    Petrol
# 1434       NaN
# 1435    Petrol
# Name: FuelType, Length: 1436, dtype: object

# %%
#Select multiple columns
df[['FuelType','Doors','Automatic']]
# Out:
#      FuelType  Doors  Automatic
# 0      Diesel  three          0
# 1      Diesel      3          0
# 2      Diesel      3          0
# 3      Diesel      3          0
# 4      Diesel      3          0
# ...       ...    ...        ...
# 1431   Petrol      3          0
# 1432   Petrol      3          0
# 1433   Petrol      3          0
# 1434      NaN      3          0
# 1435   Petrol      5          0
#
# [1436 rows x 3 columns]

# %%
#Selecting a certain row
df.loc[3]
# Out:
# Unnamed: 0         3
# Price          14950
# Age             26.0
# KM             48000
# FuelType      Diesel
# HP                90
# MetColor         0.0
# Automatic          0
# CC              2000
# Doors              3
# Weight          1165
# Name: 3, dtype: object

# %%
#Conditions - selecting rows with conditions
df[df['Price']>5000]
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
#Creating a range of numbers
import numpy as np
#convert DataFrames to Arrays
df.values
# Out:
# array([[0, 13500, 23.0, ..., 2000, 'three', 1165],
#        [1, 13750, 23.0, ..., 2000, '3', 1165],
#        [2, 13950, 24.0, ..., 2000, '3', 1165],
#        ...,
#        [1433, 8500, nan, ..., 1300, '3', 1015],
#        [1434, 7250, 70.0, ..., 1300, '3', 1015],
#        [1435, 6950, 76.0, ..., 1600, '5', 1114]], dtype=object)

# %%
A = df[['Price','Age']].values
A
# Out:
# array([[13500.,    23.],
#        [13750.,    23.],
#        [13950.,    24.],
#        ...,
#        [ 8500.,    nan],
#        [ 7250.,    70.],
#        [ 6950.,    76.]])

# %%
smalldf = df[['Price','Age','KM','FuelType','HP','MetColor','Automatic','CC','Doors','Weight']]
smalldf.to_csv('output.csv')

smalldf
# Out:
#       Price   Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986   Diesel   90       1.0          0  2000  three
# 1     13750  23.0  72937   Diesel   90       1.0          0  2000      3
# 2     13950  24.0  41711   Diesel   90       NaN          0  2000      3
# 3     14950  26.0  48000   Diesel   90       0.0          0  2000      3
# 4     13750  30.0  38500   Diesel   90       0.0          0  2000      3
# ...     ...   ...    ...      ...  ...       ...        ...   ...    ...
# 1431   7500   NaN  20544   Petrol   86       1.0          0  1300      3
# 1432  10845  72.0     ??   Petrol   86       0.0          0  1300      3
# 1433   8500   NaN  17016   Petrol   86       0.0          0  1300      3
# 1434   7250  70.0     ??      NaN   86       1.0          0  1300      3
# 1435   6950  76.0      1   Petrol  110       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...

# %%
#plotting with pandas
df['Price'].hist()
# Out:
# <Axes: >

# %%
df['Price'].plot()
# Out:
# <Axes: >

# %%
df[['Price','Age','KM','FuelType','HP','MetColor','Automatic','CC','Doors','Weight']].plot.box()
# Out:
# <Axes: >
